# %%
import pandas as pd
from sklearn.model_selection import cross_val_score, RepeatedKFold, cross_val_predict
import numpy as np

from xgboost import XGBRegressor

# %%
train_x = pd.read_csv("../results/train_x.csv")
train_y = pd.read_csv("../results/train_y.csv")
imdb_info = pd.read_csv("../results/imdb_results-with-directors.csv")

# %%
all_info = train_x.merge(imdb_info, left_on="player_1_name", right_on="title", how = "left")

# %%
all_info = all_info.merge(imdb_info, left_on="player_2_name", right_on="title", suffixes = ("_player1", "_player2"), how="left")

# %%
all_info = all_info.drop(columns=["player_1_name", "player_2_name", "title_player1", "title_player2", "imdb_id_player1", "imdb_id_player2"])

# %%
xgb_model = XGBRegressor(n_estimators=500)

results = cross_val_score(xgb_model, 
                 X = all_info,
                 y = train_y["plus_minus"],
                 scoring="neg_mean_squared_error",
                 cv=RepeatedKFold()
               )
np.sqrt(abs(results)).mean()
# Out:
# 19.01855675799774

# %%
results = cross_val_predict(xgb_model, 
                 X = all_info,
                 y = train_y["plus_minus"],
                 cv=5
               )

# %%
train_y["predicted"] = results

# %%
train_y["correct"] = np.sign(train_y["plus_minus"]) * np.sign(train_y["predicted"])

# %%
train_y.loc[train_y["correct"] == -1, :].to_csv("../results/mistakes1.3.csv", index = False)

# %%
train_y.to_csv("../results/gen_1.3_model.csv", index = False)

# %%
from eli5 import show_weights

# %%
xgb_model.fit(all_info, train_y["plus_minus"])

show_weights(xgb_model, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1157
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 cc.us_player1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0986
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 actor.Crispin Glover_player1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0862
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 director.Quentin Tarantino_player1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0827
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 player_2_seed
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0574
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 genre.Thriller_player2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0557
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lc.other_player1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.29%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0539
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 lc.es_player2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0483
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 votes_player1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0301
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 director.David Fincher_player2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0276
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 director.Ethan Coen_player2
#             </td>
#         </tr>
#
#
#
#             <tr style="background-color: hsl(120, 100.00%, 92.67%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 206 more &hellip;</i>
#                 </td>
#             </tr>
#
#
#     </tbody>
# </table>

# %%
test_x = pd.read_csv("../results/test_x.csv")
test_y = pd.read_csv("../results/test_y.csv")

# %%
test_info = test_x.merge(imdb_info, left_on="player_1_name", right_on="title", how = "left")
test_info = test_info.merge(imdb_info, left_on="player_2_name", right_on="title", suffixes = ("_player1", "_player2"), how="left")
test_info = test_info.drop(columns=["player_1_name", "player_2_name", "title_player1", "title_player2", "imdb_id_player1", "imdb_id_player2"])

# %%
xgb_model.fit(all_info, train_y["plus_minus"])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predictions = xgb_model.predict(test_info)

# %%
test_y["predictions"] = predictions

# %%
test_y
# Out:
#                             player_1_name                    player_2_name  \
# 0                               Toy Story                  The Sixth Sense
# 1                                   Fargo                         Rushmore
# 2   Eternal Sunshine of the Spotless Mind       The Umbrellas of Cherbourg
# 3              Terminator 2: Judgment Day                    The Lion King
# 4                                Magnolia              All About My Mother
# 5                  The Godfather: Part II                       In America
# 6                              Goodfellas                     Pulp Fiction
# 7                                   Fargo                         Dead Man
# 8                              Goodfellas                            Fargo
# 9                           The Godfather                     Pulp Fiction
# 10                       Schindler's List                   The Iron Giant
# 11                            Raging Bull                 Punch-Drunk Love
# 12                            Taxi Driver                   Mulholland Dr.
# 13                  2001: A Space Odyssey               Back to the Future
# 14                              Star Wars  One Flew Over the Cuckoo's Nest
# 15                           Out of Sight              Saving Private Ryan
# 16                 The Godfather: Part II                 The Big Lebowski
# 17                           Citizen Kane          Raiders of the Lost Ark
# 18               The Silence of the Lambs                 The Big Lebowski
# 19                Raiders of the Lost Ark                     The Exorcist
# 20                         Reservoir Dogs                            Se7en
# 21                           Pulp Fiction          The Empire Strikes Back
# 22                          The Apartment                            Alien
# 23                  2001: A Space Odyssey               Do The Right Thing
# 24                      Chungking Express             My Own Private Idaho
# 25                       The Big Lebowski                  The Truman Show
#
#     plus_minus  predictions
# 0           50    42.460114
# 1           44    39.029827
# 2           62    55.659367
# 3           22    28.387209
# 4           58    53.537502
# 5           82    67.279869
# 6          -20    11.777266
# 7           82    73.167229
# 8          -10    -1.419900
# 9           24    19.813684
# 10          32    17.090765
# 11          24    54.775967
# 12          20    18.993645
# 13          22     9.623795
# 14          42    21.077631
# 15         -18     8.144982
# 16          16    13.723911
# 17           8    -2.534873
# 18          10    12.105263
# 19          56    47.465981
# 20           0    24.022179
# 21          10    21.049007
# 22         -18    -3.450781
# 23          30    47.320412
# 24          16    61.888569
# 25          40    47.553703
